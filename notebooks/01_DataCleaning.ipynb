# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 0. Notes
# Data Sets:
# 1. Human Development Index --> Leave out for now
# 2. GINI Index
# 3. Gender Inequality Index --> Leave out for now
# 4. Internally Displaced Persons
# 5. Total Population
# 6. School Enrollment, Primary & Secondary, Gender Parity Index
# 7. Governance Indicators
# 8. US Foreign Aid Spending
#
# Target: Governance Indicators - World Bank (Sum percentile ranks then divide by 600)

# %%
# Keep only years from 2002-2018 (target data (aka Governance Indicators dataset)
# is most consistently recorded during that time period)

# %% [markdown]
# ## 2. GINI Index

# %%
gini = pd.read_pickle('../data/interim/gini.pkl')

# %%
gini.head()
# Out:
#   Country Name Country Code  2002  2003  2004  2005  2006  2007  2008  2009  \
# 0        Aruba          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Angola          AGO   NaN   NaN   NaN   NaN   NaN   NaN  42.7   NaN
# 3      Albania          ALB  31.7   NaN   NaN  30.6   NaN   NaN  30.0   NaN
# 4      Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN  29.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
gini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   Country Code  264 non-null    object
#  2   2002          47 non-null     float64
#  3   2003          55 non-null     float64
#  4   2004          71 non-null     float64
#  5   2005          75 non-null     float64
#  6   2006          74 non-null     float64
#  7   2007          72 non-null     float64
#  8   2008          73 non-null     float64
#  9   2009          78 non-null     float64
#  10  2010          84 non-null     float64
#  11  2011          77 non-null     float64
#  12  2012          79 non-null     float64
#  13  2013          76 non-null     float64
#  14  2014          76 non-null     float64
#  15  2015          75 non-null     float64
#  16  2016          39 non-null     float64
# ...

# %% [markdown]
# ## 4. Internally Displaced Persons

# %%
displaced = pd.read_pickle('../data/interim/displaced.pkl')

# %%
displaced.head()
# Out:
#   Country Name Country Code  2002  2003  2004  2005  2006  2007  2008  \
# 0        Aruba          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Angola          AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      Albania          ALB   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        2009      2010      2011      2012      2013      2014       2015  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1  297000.0  352000.0  450000.0  492000.0  631000.0  805000.0  1174000.0
# 2       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN        NaN
#
#         2016       2017       2018
# 0        NaN        NaN        NaN
# ...

# %%
displaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   Country Code  264 non-null    object
#  2   2002          0 non-null      float64
#  3   2003          0 non-null      float64
#  4   2004          0 non-null      float64
#  5   2005          0 non-null      float64
#  6   2006          0 non-null      float64
#  7   2007          0 non-null      float64
#  8   2008          0 non-null      float64
#  9   2009          55 non-null     float64
#  10  2010          56 non-null     float64
#  11  2011          57 non-null     float64
#  12  2012          58 non-null     float64
#  13  2013          63 non-null     float64
#  14  2014          68 non-null     float64
#  15  2015          62 non-null     float64
#  16  2016          71 non-null     float64
# ...

# %% [markdown]
# ***Potentially an issue that we only have data from 2009 on***

# %% [markdown]
# ## 5. Total Population

# %%
population = read_pickle('../data/interim/population.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-d572aed0fa9b> in <module>
# ----> 1 population = read_pickle('../data/interim/population.pkl')
#
# NameError: name 'read_pickle' is not defined

# %%
population.head()
# Out:
#   Country Name Country Code        2002        2003        2004        2005  \
# 0        Aruba          ABW     94992.0     97017.0     98737.0    100031.0
# 1  Afghanistan          AFG  22600770.0  23680871.0  24726684.0  25654277.0
# 2       Angola          AGO  17519417.0  18121479.0  18758145.0  19433602.0
# 3      Albania          ALB   3051010.0   3039616.0   3026939.0   3011487.0
# 4      Andorra          AND     70049.0     73182.0     76244.0     78867.0
#
#          2006        2007        2008        2009        2010        2011  \
# 0    100834.0    101222.0    101358.0    101455.0    101669.0    102046.0
# 1  26433049.0  27100536.0  27722276.0  28394813.0  29185507.0  30117413.0
# 2  20149901.0  20905363.0  21695634.0  22514281.0  23356246.0  24220661.0
# 3   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0   2905195.0
# 4     80993.0     82684.0     83862.0     84463.0     84449.0     83747.0
#
# ...

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   Country Code  264 non-null    object
#  2   2002          263 non-null    float64
#  3   2003          263 non-null    float64
#  4   2004          263 non-null    float64
#  5   2005          263 non-null    float64
#  6   2006          263 non-null    float64
#  7   2007          263 non-null    float64
#  8   2008          263 non-null    float64
#  9   2009          263 non-null    float64
#  10  2010          263 non-null    float64
#  11  2011          263 non-null    float64
#  12  2012          262 non-null    float64
#  13  2013          262 non-null    float64
#  14  2014          262 non-null    float64
#  15  2015          262 non-null    float64
#  16  2016          262 non-null    float64
# ...

# %% [markdown]
# ## 6. Gender Parity Index - Primary & Secondary School Enrollment

# %%
gpi_school = WorldBankData('../data/raw/SchoolEnrollment_GenderParityIndex.csv')

# %%
gpi_school.head()
# Out:
#   Country Name Country Code   2002     2003     2004     2005     2006  \
# 0        Aruba          ABW  0.989  0.97706  0.95291  0.96339  0.96798
# 1  Afghanistan          AFG    NaN  0.54426  0.40582  0.54769  0.57323
# 2       Angola          AGO    NaN      NaN      NaN      NaN      NaN
# 3      Albania          ALB    NaN      NaN  0.98020  0.97804  0.98504
# 4      Andorra          AND    NaN      NaN      NaN      NaN      NaN
#
#       2007     2008     2009     2010     2011     2012     2013     2014  \
# 0  0.98676  1.00561  1.00444  1.01460  1.00871  1.02156      NaN      NaN
# 1  0.56720  0.58602  0.60961  0.62581  0.66345  0.66925  0.65533  0.65402
# 2      NaN  0.83309  0.82340  0.77763  0.63032      NaN      NaN      NaN
# 3  0.99687  0.99979  1.01781  1.00569  1.00029  0.99010  0.98159  0.97668
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2015     2016     2017    2018
# 0      NaN      NaN      NaN     NaN
# ...

# %%
gpi_school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   Country Code  264 non-null    object
#  2   2002          180 non-null    float64
#  3   2003          176 non-null    float64
#  4   2004          188 non-null    float64
#  5   2005          190 non-null    float64
#  6   2006          184 non-null    float64
#  7   2007          187 non-null    float64
#  8   2008          186 non-null    float64
#  9   2009          185 non-null    float64
#  10  2010          184 non-null    float64
#  11  2011          190 non-null    float64
#  12  2012          185 non-null    float64
#  13  2013          171 non-null    float64
#  14  2014          181 non-null    float64
#  15  2015          181 non-null    float64
#  16  2016          174 non-null    float64
# ...

# %% [markdown]
# ## 7. Governance Indicators

# %%
gov_indicators = pd.read_csv('../data/raw/GovernanceIndicators.csv')

# %%
gov_indicators.head(20)
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 1      Afghanistan          AFG
# 2      Afghanistan          AFG
# 3      Afghanistan          AFG
# 4      Afghanistan          AFG
# 5      Afghanistan          AFG
# 6          Albania          ALB
# 7          Albania          ALB
# 8          Albania          ALB
# 9          Albania          ALB
# 10         Albania          ALB
# 11         Albania          ALB
# 12         Algeria          DZA
# 13         Algeria          DZA
# 14         Algeria          DZA
# 15         Algeria          DZA
# 16         Algeria          DZA
# 17         Algeria          DZA
# 18  American Samoa          ASM
# 19  American Samoa          ASM
#
#                                           Series Name Series Code  \
# 0           Voice and Accountability: Percentile Rank  VA.PER.RNK
# 1                        Rule of Law: Percentile Rank  RL.PER.RNK
# 2                 Regulatory Quality: Percentile Rank  RQ.PER.RNK
# ...

# %% [markdown]
# Things to work on:

# %%
gov_indicators['Country Code'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'AIA', 'ATG', 'ARG',
#        'ARM', 'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB',
#        'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA',
#        'BRA', 'BRN', 'BGR', 'BFA', 'BDI', 'CPV', 'KHM', 'CMR', 'CAN',
#        'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COD', 'COG',
#        'COK', 'CRI', 'CIV', 'HRV', 'CUB', 'CYP', 'CZE', 'DNK', 'DJI',
#        'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'SWZ',
#        'ETH', 'FJI', 'FIN', 'FRA', 'GUF', 'GAB', 'GMB', 'GEO', 'DEU',
#        'GHA', 'GRC', 'GRL', 'GRD', 'GUM', 'GTM', 'GIN', 'GNB', 'GUY',
#        'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ',
#        'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JEY', 'JOR', 'KAZ', 'KEN',
#        'KIR', 'PRK', 'KOR', 'XKX', 'KWT', 'KGZ', 'LAO', 'LVA', 'LBN',
#        'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX', 'MAC', 'MDG', 'MWI',
# ...

# %%
gov_indicators.info()
#Maybe want to cut data down to 2002-2018 for all datasets since those are the years we have annual targets for
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1289 entries, 0 to 1288
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   1286 non-null   object
#  1   Country Code   1284 non-null   object
#  2   Series Name    1284 non-null   object
#  3   Series Code    1284 non-null   object
#  4   1996 [YR1996]  1284 non-null   object
#  5   1998 [YR1998]  1284 non-null   object
#  6   2000 [YR2000]  1284 non-null   object
#  7   2002 [YR2002]  1284 non-null   object
#  8   2003 [YR2003]  1284 non-null   object
#  9   2004 [YR2004]  1284 non-null   object
#  10  2005 [YR2005]  1284 non-null   object
#  11  2006 [YR2006]  1284 non-null   object
#  12  2007 [YR2007]  1284 non-null   object
#  13  2008 [YR2008]  1284 non-null   object
#  14  2009 [YR2009]  1284 non-null   object
#  15  2010 [YR2010]  1284 non-null   object
#  16  2011 [YR2011]  1284 non-null   object
# ...

# %% [markdown]
# ## 8. US Foreign Aid Spending

# %%
usaid = pd.read_csv('../data/raw/us_foreign_aid_complete.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
usaid['country_code'].unique()
# Out:
# array(['AFG', 'IRQ', 'POL', 'GBR', nan, 'ISR', 'WLD', 'EGY', 'FRA', 'MEN',
#        'COL', 'RUS', 'JOR', 'ASN', 'PAK', 'ITA', 'TUR', 'MEX', 'IND',
#        'CNA', 'GRC', 'EUS', 'EEN', 'SSN', 'KOR', 'WAN', 'HTI', 'SLV',
#        'DEU', 'ESP', 'PAN', 'JPN', 'NLD', 'KHM', 'WEC', 'TZA', 'TWN',
#        'MNS', 'PHL', 'BDI', 'SDF', 'BEL', 'SEN', 'PSE', 'PRT', 'MOZ',
#        'LAO', 'UGA', 'AUT', 'ZMB', 'SOM', 'BIH', 'KEN', 'NGA', 'GEO',
#        'IDN', 'YEM', 'BGD', 'NOR', 'ZAF', 'BRA', 'CIV', 'SYR', 'UKR',
#        'NIC', 'SCG', 'SSD', 'LCN', 'PER', 'CRI', 'HND', 'EES', 'LBN',
#        'MAR', 'MNG', 'IRN', 'MWI', 'CS-KM', 'KAZ', 'MLI', 'MHL', 'LBR',
#        'GTM', 'BFA', 'CHL', 'EEE', 'LAN', 'SDN', 'MDA', 'ETH', 'BWA',
#        'BOL', 'GHA', 'DOM', 'JAM', 'NER', 'ARM', 'LBY', 'OCN', 'DNK',
#        'ENS', 'TUN', 'ARG', 'PLW', 'THA', 'ANS', 'BHR', 'FSM', 'MDG',
#        'IRL', 'SAU', 'PRK', 'OMN', 'BEN', 'EUN', 'ZWE', 'LSO', 'NAM',
# ...

# %%
usaid['fiscal_year'].unique()
# Out:
# array(['2011', '2012', '2013', '2015', '2010', '2008', '2009', '2006',
#        '2018', '2014', '2017', '2007', '2003', '2016', '1947', '1973',
#        '2000', '1979', '1972', '1995', '2005', '2004', '1996', '2002',
#        '1993', '2001', '1985', '1994', '1986', '1999', '1991', '1971',
#        '1992', '1987', '1988', '1998', '1989', '1997', '1990', '1974',
#        '1970', '1952', '1949', '1984', '1969', '1951', '1982', '2019',
#        '1983', '1980', '1981', '1978', '1968', '1950', '1976', '1977',
#        '1954', '1946', '1967', '1966', '1975', '1976tq', '1962', '1956',
#        '1953', '1948', '1963', '1959', '1957', '1965', '1955', '1964',
#        '1960', '1961', '1958', 2003, 2002, 2016, 2017, 2018, 2008, 2011,
#        2010, 2012, 2015, 2019, 2006, 2005, 2013, 2014, 1999, 2007, 1996,
#        2004, 2009, 2001, 1993, 1995, 1998, 1997, 2000, 1978, 1986, 1994,
#        1963, 1985, 1966, 1957, 1968, 1956, 1961, 1974, 1972, 1987, 1992,
# ...

# %% [markdown]
# ## 1. HDI Raw Data

# %%
#hdi = pd.read_csv('../data/raw/HumanDevelopmentIndex.csv', skiprows=[0])

# %%
#hdi.head()

# %% [markdown]
# Initial things to clean up:
#
# 2. Drop NaN columns
# 3. Drop HDI Rank (2018)
# 4. Convert '..' to NaN

# %%
#Drop all columns with NaN values (includes 'HDI Rank (2018)')
#hdi.dropna(axis=1, inplace=True)

#Convert '..' entries to NaN
#hdi.replace('..', np.nan, inplace=True)

# %%
#hdi.head()

# %%
#hdi.info()

# %%
#Drop rows without data for 2017-2018 (they're title rows for 'Human Development' and 'Regions')
#hdi.dropna(subset=['2017', '2018'], inplace=True)

# %% [markdown]
# #### Save cleaned dataset to interim data folder:

# %%
#hdi.to_pickle('../data/interim/HDI.pkl')

# %% [markdown]
# ## 3. Gender Inequality Index

# %%
#gii = pd.read_csv('../data/raw/GenderInequalityIndex.csv', skiprows=[0])

# %%
#gii.head()

# %%
#gii.info()
